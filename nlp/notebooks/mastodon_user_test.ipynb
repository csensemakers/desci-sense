# %%
import sys
sys.path.append("../")

from urllib.parse import urlparse
import pandas as pd
from mastodon import Mastodon

from desci_sense.shared_functions.schema.post import RefPost
from desci_sense.shared_functions.dataloaders.mastodon.mastodon_loader import MastodonLoader

# %%
# create mastodon api token (https://sohwatt.com/generating-a-token-on-mastodon/)
# and set as environment variable using `export MASTODON_ACCESS_TOKEN="your_access_token_here"`
mloader = MastodonLoader()

# %%
accts = ["@ronent@mastodon.social"]
posts = mloader.load_profiles(mastodon_accounts=accts)

# %%
posts
# Out:
# [RefPost(author='Ronen Tamari', content='Also relevant for discussions about science social media as critical\nscientific infrastructure @UlrikeHahn @brembs @jonny @bonfire indieweb.social\n@nanopub\n\n" TikTokification of academia"\n\nhttps://arxiv.org/abs/2401.13782\n\nhttps://twitter.com/deliprao/status/1750732070014337101', url='https://mastodon.social/@ronent/111822571204212368', created_at=datetime.datetime(2024, 1, 26, 13, 50, 26, 443000, tzinfo=tzutc()), metadata={'id': 111822571204212368, 'created_at': datetime.datetime(2024, 1, 26, 13, 50, 26, 443000, tzinfo=tzutc()), 'in_reply_to_id': None, 'in_reply_to_account_id': None, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/ronent/statuses/111822571204212368', 'url': 'https://mastodon.social/@ronent/111822571204212368', 'replies_count': 2, 'reblogs_count': 5, 'favourites_count': 3, 'edited_at': datetime.datetime(2024, 1, 26, 13, 51, 54, 433000, tzinfo=tzutc()), 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'pinned': False, 'content': '<p>Also relevant for discussions about science social media as critical scientific infrastructure <span class="h-card" translate="no"><a href="https://fediscience.org/@UlrikeHahn" class="u-url mention">@<span>UlrikeHahn</span></a></span>  <span class="h-card" translate="no"><a href="https://mastodon.social/@brembs" class="u-url mention">@<span>brembs</span></a></span> <span class="h-card" translate="no"><a href="https://social.coop/@jonny" class="u-url mention">@<span>jonny</span></a></span>  <span class="h-card" translate="no"><a href="https://indieweb.social/@bonfire" class="u-url mention">@<span>bonfire</span></a></span> indieweb.social  <span class="h-card" translate="no"><a href="https://mas.to/@nanopub" class="u-url mention">@<span>nanopub</span></a></span>  </p><p>&quot; TikTokification of academia&quot;</p><p><a href="https://arxiv.org/abs/2401.13782" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="">arxiv.org/abs/2401.13782</span><span class="invisible"></span></a> </p><p><a href="https://twitter.com/deliprao/status/1750732070014337101" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">twitter.com/deliprao/status/17</span><span class="invisible">50732070014337101</span></a></p>', 'filtered': [], 'reblog': None, 'application': {'name': 'Web', 'website': None}, 'account': {'id': 107714271376772838, 'username': 'ronent', 'acct': 'ronent', 'display_name': 'Ronen Tamari', 'locked': False, 'bot': False, 'discoverable': True, 'indexable': False, 'group': False, 'created_at': datetime.datetime(2022, 1, 31, 0, 0, tzinfo=tzutc()), 'note': '<p>Researcher and entrepreneur @ Astera Institute | building collective sensemaking systems for science | Interested in prosocial tech, artificial/natural/collective intelligence and all their combinations.<br />Co-founder of  Common SenseMakers (<a href="https://www.csensemakers.com/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="">csensemakers.com/</span><span class="invisible"></span></a>)</p>', 'url': 'https://mastodon.social/@ronent', 'uri': 'https://mastodon.social/users/ronent', 'avatar': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'avatar_static': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'header': 'https://mastodon.social/headers/original/missing.png', 'header_static': 'https://mastodon.social/headers/original/missing.png', 'followers_count': 158, 'following_count': 372, 'statuses_count': 86, 'last_status_at': datetime.datetime(2024, 2, 9, 0, 0), 'hide_collections': False, 'noindex': False, 'emojis': [], 'roles': [], 'fields': [{'name': 'Webpage', 'value': ...
#  RefPost(author='Ronen Tamari', content='Thanks for reading! Happy new year, make merry and make sense! 🎉💡 23/23', url='https://mastodon.social/@ronent/111687085875576875', created_at=datetime.datetime(2024, 1, 2, 15, 34, 44, 379000, tzinfo=tzutc()), metadata={'id': 111687085875576875, 'created_at': datetime.datetime(2024, 1, 2, 15, 34, 44, 379000, tzinfo=tzutc()), 'in_reply_to_id': 111687084670741683, 'in_reply_to_account_id': 107714271376772838, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/ronent/statuses/111687085875576875', 'url': 'https://mastodon.social/@ronent/111687085875576875', 'replies_count': 1, 'reblogs_count': 0, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'pinned': False, 'content': '<p>Thanks for reading! Happy new year, make merry and make sense! 🎉💡 23/23</p>', 'filtered': [], 'reblog': None, 'application': {'name': 'Web', 'website': None}, 'account': {'id': 107714271376772838, 'username': 'ronent', 'acct': 'ronent', 'display_name': 'Ronen Tamari', 'locked': False, 'bot': False, 'discoverable': True, 'indexable': False, 'group': False, 'created_at': datetime.datetime(2022, 1, 31, 0, 0, tzinfo=tzutc()), 'note': '<p>Researcher and entrepreneur @ Astera Institute | building collective sensemaking systems for science | Interested in prosocial tech, artificial/natural/collective intelligence and all their combinations.<br />Co-founder of  Common SenseMakers (<a href="https://www.csensemakers.com/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="">csensemakers.com/</span><span class="invisible"></span></a>)</p>', 'url': 'https://mastodon.social/@ronent', 'uri': 'https://mastodon.social/users/ronent', 'avatar': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'avatar_static': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'header': 'https://mastodon.social/headers/original/missing.png', 'header_static': 'https://mastodon.social/headers/original/missing.png', 'followers_count': 158, 'following_count': 372, 'statuses_count': 86, 'last_status_at': datetime.datetime(2024, 2, 9, 0, 0), 'hide_collections': False, 'noindex': False, 'emojis': [], 'roles': [], 'fields': [{'name': 'Webpage', 'value': '<a href="https://ronentk.github.io/" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">ronentk.github.io/</span><span class="invisible"></span></a>', 'verified_at': None}, {'name': 'Twitter', 'value': '<a href="https://twitter.com/rtk254" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">twitter.com/rtk254</span><span class="invisible"></span></a>', 'verified_at': None}]}, 'media_attachments': [], 'mentions': [], 'tags': [], 'emojis': [], 'card': None, 'poll': None, 'plain_content': 'Thanks for reading! Happy new year, make merry and make sense! 🎉💡 23/23'}, source_network='mastodon'),
#  RefPost(author='Ronen Tamari', content="Shout-outs to some awesome ppl/orgs we've already started working with\n(hopefully more to come soon!):  \n  \nhttps://twitter.com/rtk254/status/1741841747825610869\n\nAnd we’re always looking for fellow collaborators, so please reach out! 22/", url='https://mastodon.social/@ronent/111687084670741683', created_at=datetime.datetime(2024, 1, 2, 15, 34, 25, 928000, tzinfo=tzutc()), metadata={'id': 111687084670741683, 'created_at': datetime.datetime(2024, 1, 2, 15, 34, 25, 928000, tzinfo=tzutc()), 'in_reply_to_id': 111687079492648450, 'in_reply_to_account_id': 107714271376772838, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/ronent/statuses/111687084670741683', 'url': 'https://mastodon.social/@ronent/111687084670741683', 'replies_count': 1, 'reblogs_count': 0, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'pinned': False, 'content': '<p>Shout-outs to some awesome ppl/orgs we&#39;ve already started working with (hopefully more to come soon!):<br />    <br /><a href="https://twitter.com/rtk254/status/1741841747825610869" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">twitter.com/rtk254/status/1741</span><span class="invisible">841747825610869</span></a></p><p>And we’re always looking for fellow collaborators, so please reach out! 22/</p>', 'filtered': [], 'reblog': None, 'application': {'name': 'Web', 'website': None}, 'account': {'id': 107714271376772838, 'username': 'ronent', 'acct': 'ronent', 'display_name': 'Ronen Tamari', 'locked': False, 'bot': False, 'discoverable': True, 'indexable': False, 'group': False, 'created_at': datetime.datetime(2022, 1, 31, 0, 0, tzinfo=tzutc()), 'note': '<p>Researcher and entrepreneur @ Astera Institute | building collective sensemaking systems for science | Interested in prosocial tech, artificial/natural/collective intelligence and all their combinations.<br />Co-founder of  Common SenseMakers (<a href="https://www.csensemakers.com/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="">csensemakers.com/</span><span class="invisible"></span></a>)</p>', 'url': 'https://mastodon.social/@ronent', 'uri': 'https://mastodon.social/users/ronent', 'avatar': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'avatar_static': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'header': 'https://mastodon.social/headers/original/missing.png', 'header_static': 'https://mastodon.social/headers/original/missing.png', 'followers_count': 158, 'following_count': 372, 'statuses_count': 86, 'last_status_at': datetime.datetime(2024, 2, 9, 0, 0), 'hide_collections': False, 'noindex': False, 'emojis': [], 'roles': [], 'fields': [{'name': 'Webpage', 'value': '<a href="https://ronentk.github.io/" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">ronentk.github.io/</span><span class="invisible"></span></a>', 'verified_at': None}, {'name': 'Twitter', 'value': '<a href="https://twitter.com/rtk254" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">twitter.com/rtk254</span><span class="invisible"></span></a>', 'verified_at': None}]}, 'media_attachments': [], 'mentions': [], 'tags': [], 'emojis': [], 'card': {'url': 'https://twitter.com/rtk254/status/1741841747825610869', 'title': 'Ronen Tamari (@rtk254) on X', 'description': "@AsteraInstitute @nanopub_org Shout-outs to some awesome ppl/orgs we've already started working with (hopefully more to come soon!):\n    @nanopub_org @DeSciLabs @JoelChan86 @aka_MatsuLab @CSenseMakers @pepoospina @ShaRefO ...
#  RefPost(author='Ronen Tamari', content="Our goal is not to build yet another social media platform! 🏰 Rather, open +\ncollaborative ecosystems are both the means and ends of the project. That’s\nwhy we're building partnerships with mission-aligned orgs to evolve this new\necosystem, together 🤝 21/", url='https://mastodon.social/@ronent/111687079492648450', created_at=datetime.datetime(2024, 1, 2, 15, 33, 6, 983000, tzinfo=tzutc()), metadata={'id': 111687079492648450, 'created_at': datetime.datetime(2024, 1, 2, 15, 33, 6, 983000, tzinfo=tzutc()), 'in_reply_to_id': 111687078527305926, 'in_reply_to_account_id': 107714271376772838, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/ronent/statuses/111687079492648450', 'url': 'https://mastodon.social/@ronent/111687079492648450', 'replies_count': 1, 'reblogs_count': 0, 'favourites_count': 1, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'pinned': False, 'content': '<p>Our goal is not to build yet another social media platform! 🏰 Rather, open + collaborative ecosystems are both the means and ends of the project. That’s why we&#39;re building partnerships with mission-aligned orgs to evolve this new ecosystem, together 🤝 21/</p>', 'filtered': [], 'reblog': None, 'application': {'name': 'Web', 'website': None}, 'account': {'id': 107714271376772838, 'username': 'ronent', 'acct': 'ronent', 'display_name': 'Ronen Tamari', 'locked': False, 'bot': False, 'discoverable': True, 'indexable': False, 'group': False, 'created_at': datetime.datetime(2022, 1, 31, 0, 0, tzinfo=tzutc()), 'note': '<p>Researcher and entrepreneur @ Astera Institute | building collective sensemaking systems for science | Interested in prosocial tech, artificial/natural/collective intelligence and all their combinations.<br />Co-founder of  Common SenseMakers (<a href="https://www.csensemakers.com/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="">csensemakers.com/</span><span class="invisible"></span></a>)</p>', 'url': 'https://mastodon.social/@ronent', 'uri': 'https://mastodon.social/users/ronent', 'avatar': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'avatar_static': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'header': 'https://mastodon.social/headers/original/missing.png', 'header_static': 'https://mastodon.social/headers/original/missing.png', 'followers_count': 158, 'following_count': 372, 'statuses_count': 86, 'last_status_at': datetime.datetime(2024, 2, 9, 0, 0), 'hide_collections': False, 'noindex': False, 'emojis': [], 'roles': [], 'fields': [{'name': 'Webpage', 'value': '<a href="https://ronentk.github.io/" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">ronentk.github.io/</span><span class="invisible"></span></a>', 'verified_at': None}, {'name': 'Twitter', 'value': '<a href="https://twitter.com/rtk254" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">twitter.com/rtk254</span><span class="invisible"></span></a>', 'verified_at': None}]}, 'media_attachments': [], 'mentions': [], 'tags': [], 'emojis': [], 'card': None, 'poll': None, 'plain_content': "Our goal is not to build yet another social media platform! 🏰 Rather, open +\ncollaborative ecosystems are both the means and ends of the project. That’s\nwhy we're building partnerships with mission-aligned orgs to evolve this new\necosystem, together 🤝 21/"}, source_network='mastodon'),
#  RefPost(author='Ronen Tamari', content='Different from services that track researchers unknowingly, we’re committed to\nconsentful tech and participatory data practices. We see data sharing and\ncollection as intentional practices employed by communities, for communities,\nto support collective sensemaking 20/\nhttps://twitter.com/rtk254/status/1528742051461865472', url='https://mastodon.social/@ronent/111687078527305926', created_at=datetime.datetime(2024, 1, 2, 15, 32, 52, 254000, tzinfo=tzutc()), metadata={'id': 111687078527305926, 'created_at': datetime.datetime(2024, 1, 2, 15, 32, 52, 254000, tzinfo=tzutc()), 'in_reply_to_id': 111687077151690591, 'in_reply_to_account_id': 107714271376772838, 'sensitive': False, 'spoiler_text': '', 'visibility': 'public', 'language': 'en', 'uri': 'https://mastodon.social/users/ronent/statuses/111687078527305926', 'url': 'https://mastodon.social/@ronent/111687078527305926', 'replies_count': 1, 'reblogs_count': 0, 'favourites_count': 0, 'edited_at': None, 'favourited': False, 'reblogged': False, 'muted': False, 'bookmarked': False, 'pinned': False, 'content': '<p>Different from services that track researchers unknowingly, we’re committed to consentful tech and participatory data practices. We see data sharing and collection as intentional practices employed by communities, for communities, to support collective sensemaking 20/ <a href="https://twitter.com/rtk254/status/1528742051461865472" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://</span><span class="ellipsis">twitter.com/rtk254/status/1528</span><span class="invisible">742051461865472</span></a></p>', 'filtered': [], 'reblog': None, 'application': {'name': 'Web', 'website': None}, 'account': {'id': 107714271376772838, 'username': 'ronent', 'acct': 'ronent', 'display_name': 'Ronen Tamari', 'locked': False, 'bot': False, 'discoverable': True, 'indexable': False, 'group': False, 'created_at': datetime.datetime(2022, 1, 31, 0, 0, tzinfo=tzutc()), 'note': '<p>Researcher and entrepreneur @ Astera Institute | building collective sensemaking systems for science | Interested in prosocial tech, artificial/natural/collective intelligence and all their combinations.<br />Co-founder of  Common SenseMakers (<a href="https://www.csensemakers.com/" target="_blank" rel="nofollow noopener noreferrer" translate="no"><span class="invisible">https://www.</span><span class="">csensemakers.com/</span><span class="invisible"></span></a>)</p>', 'url': 'https://mastodon.social/@ronent', 'uri': 'https://mastodon.social/users/ronent', 'avatar': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'avatar_static': 'https://files.mastodon.social/accounts/avatars/107/714/271/376/772/838/original/9331699b5c120ed4.jpg', 'header': 'https://mastodon.social/headers/original/missing.png', 'header_static': 'https://mastodon.social/headers/original/missing.png', 'followers_count': 158, 'following_count': 372, 'statuses_count': 86, 'last_status_at': datetime.datetime(2024, 2, 9, 0, 0), 'hide_collections': False, 'noindex': False, 'emojis': [], 'roles': [], 'fields': [{'name': 'Webpage', 'value': '<a href="https://ronentk.github.io/" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">ronentk.github.io/</span><span class="invisible"></span></a>', 'verified_at': None}, {'name': 'Twitter', 'value': '<a href="https://twitter.com/rtk254" target="_blank" rel="nofollow noopener noreferrer me" translate="no"><span class="invisible">https://</span><span class="">twitter.com/rtk254</span><span class="invisible"></span></a>', 'verified_at': None}]}, 'media_attachments': [], 'mentions': [], 'tags': [], 'emojis': [], 'card': {'url': 'https://twitter.com/rtk254/status/1528742051461865472', 'title': 'Ronen Tamari (@rtk254) on X', 'description': '1/Excited to share some new work on collective sensemaking! We’ll present  ...
