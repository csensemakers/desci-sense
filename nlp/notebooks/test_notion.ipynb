# %%
import sys
sys.path.append("../")

import pandas as pd

from desci_sense.schema.notion_ontology_base import NotionOntologyBase

# %%
notion_ontology = NotionOntologyBase(versions=['v0'])

# %%
notion_ontology.ont_df
# Out:
#                                                display_name  \
# Name
# possible-missing-reference     ⬛ possible-missing-reference
# dg-observation                🔭 discourse-graph/observation
# dg-claim                            🫴 discourse-graph/claim
# dg-question                      ❓ discourse-graph/question
# watching-consumption-status               👀 watching-status
# reading-consumption-status                 📑 reading-status
# listening-consumption-status             🎧 listening-status
# links to                                         🔗 links-to
# reviews                                           🧐 reviews
# recommends                                     👌 recommends
# asks-question-about                    ❔ ask-question-about
# Includes-quotation-from                       📝 quotes-from
# Discussion                                     🗣️ discusses
# Announcement-event                       🗓️ announces-event
# announcement-job                            📢 announces-job
# Announcement-research                  📢 announces-research
#
#                                                                             URI  \
# Name
# possible-missing-reference                                                 None
# dg-observation                                                             None
# dg-claim                                                                   None
# dg-question                                                                None
# watching-consumption-status                                                None
# reading-consumption-status                                                 None
# listening-consumption-status                                               None
# links to                      https://sparontologies.github.io/cito/current/...
# reviews                                                                    None
# recommends                                                                 None
# asks-question-about                                                        None
# Includes-quotation-from       https://sparontologies.github.io/cito/current/...
# Discussion                    https://sparontologies.github.io/cito/current/...
# Announcement-event                                                         None
# announcement-job                                                           None
# Announcement-research                                                      None
#
#                                        label  \
# Name
# possible-missing-reference       missing-ref
# dg-observation                dg-observation
# dg-claim                            dg-claim
# dg-question                      dg-question
# watching-consumption-status         watching
# reading-consumption-status           reading
# listening-consumption-status       listening
# links to                               other
# reviews                               review
# recommends                    recommendation
# asks-question-about                 question
# Includes-quotation-from                quote
# Discussion                        discussion
# Announcement-event                     event
# announcement-job                         job
# Announcement-research               announce
#
#                                                                          prompt  \
# Name
# possible-missing-reference    this post seems to be referring to a reference...
# dg-observation                this post is articulating a single, highly obs...
# dg-claim                           this post is articulating an idea or a claim
# dg-question                           this post is raising a research question.
# watching-consumption-status   this post describes the watching status of the...
# reading-consumption-status    this post describes the reading status of the ...
# listening-consumption-status  this post describes the listening status of th...
# links to                      This is a special tag. Use this tag if none of...
# reviews                       this post contains a review of another referen...
# recommends                    The author is recommending any kind of content...
# asks-question-about           this post is raising a question or questions a...
# Includes-quotation-from       this post is quoting text from an article it's...
# Discussion                    this post discusses how the cited reference re...
# Announcement-event            this post includes an invitation to an event, ...
# announcement-job              this post describes a job listing, for example...
# Announcement-research         this post contains an announcement of new rese...
#
#                                                                           notes  \
# Name
# possible-missing-reference                                                 None
# dg-observation                                                             None
# dg-claim                                                                   None
# dg-question                                                                None
# watching-consumption-status                                                None
# reading-consumption-status                                                 None
# listening-consumption-status                                               None
# links to                      default predicate for a mention of a URL (alwa...
# reviews                                                                    None
# recommends                                                                 None
# asks-question-about                                                        None
# Includes-quotation-from                                                    None
# Discussion                                                                 None
# Announcement-event                                                         None
# announcement-job                                                           None
# Announcement-research                                                      None
#
#                              valid_subject_types valid_object_types versions
# Name
# possible-missing-reference                [post]              [nan]     [v0]
# dg-observation                            [post]              [nan]     [v0]
# dg-claim                                  [post]              [nan]     [v0]
# dg-question                               [post]              [nan]     [v0]
# watching-consumption-status               [post]              [ref]     [v0]
# reading-consumption-status                [post]              [ref]     [v0]
# listening-consumption-status              [post]              [ref]     [v0]
# links to                                  [post]         [ref, nan]     [v0]
# reviews                              [post, ref]              [ref]     [v0]
# recommends                           [post, ref]              [ref]     [v0]
# asks-question-about                  [post, ref]              [ref]     [v0]
# Includes-quotation-from              [post, ref]              [ref]     [v0]
# Discussion                           [post, ref]              [ref]     [v0]
# Announcement-event                        [post]              [ref]     [v0]
# announcement-job                          [post]              [ref]     [v0]
# Announcement-research                [post, ref]              [ref]     [v0]

# %%
ont_df = notion_ontology.ont_df

# %%
ont_df.loc[["Discussion", "reviews"]]
# Out:
#             display_name                                                URI  \
# Name
# Discussion  🗣️ discusses  https://sparontologies.github.io/cito/current/...
# reviews        🧐 reviews                                               None
#
#                  label                                             prompt  \
# Name
# Discussion  discussion  this post discusses how the cited reference re...
# reviews         review  this post contains a review of another referen...
#
#            notes valid_subject_types valid_object_types versions
# Name
# Discussion  None         [post, ref]              [ref]     [v0]
# reviews     None         [post, ref]              [ref]     [v0]

# %%
"reviews" in notion_ontology.dis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 "reviews" in notion_ontology.display_name_df
#
# AttributeError: 'NotionOntologyBase' object has no attribute 'display_name_df'

# %%
ont_df.display_name.to_list()
# Out:
# ['⬛ possible-missing-reference',
#  '🔭 discourse-graph/observation',
#  '🫴 discourse-graph/claim',
#  ' ❓ discourse-graph/question',
#  '👀 watching-status',
#  '📑 reading-status',
#  '🎧 listening-status',
#  '🔗 links-to',
#  '🧐 reviews',
#  '👌 recommends',
#  '❔ ask-question-about',
#  '📝 quotes-from',
#  '🗣️ discusses',
#  '🗓️ announces-event',
#  '📢 announces-job',
#  '📢 announces-research']

# %%
label_key_df = ont_df.set_index("label")
label_key_df.loc["missing-ref"]["display_name"]
# Out:
# '⬛ possible-missing-reference'

# %%
ont_df.to_dict(orient='index')
# Out:
# {'possible-missing-reference': {'display_name': '⬛ possible-missing-reference',
#   'URI': None,
#   'label': 'missing-ref',
#   'prompt': 'this post seems to be referring to a reference by name but has not explicitly provided a URL link to the reference. For example, a post that discusses a book and mentions it by title, but contains no link to the book.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['nan'],
#   'versions': ['v0']},
#  'dg-observation': {'display_name': '🔭 discourse-graph/observation',
#   'URI': None,
#   'label': 'dg-observation',
#   'prompt': 'this post is articulating a single, highly observation. The intuition is that observation notes should be as close to “the data” as possible. They should be similar to how results are described in results sections of academic publications.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['nan'],
#   'versions': ['v0']},
#  'dg-claim': {'display_name': '🫴 discourse-graph/claim',
#   'URI': None,
#   'label': 'dg-claim',
#   'prompt': 'this post is articulating an idea or a claim',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['nan'],
#   'versions': ['v0']},
#  'dg-question': {'display_name': ' ❓ discourse-graph/question',
#   'URI': None,
#   'label': 'dg-question',
#   'prompt': 'this post is raising a research question.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['nan'],
#   'versions': ['v0']},
#  'watching-consumption-status': {'display_name': '👀 watching-status',
#   'URI': None,
#   'label': 'watching',
#   'prompt': 'this post describes the watching status of the author in relation to a reference, such as a video or movie. The author may have watched the content in the past, is watching the content in the present, or is looking forward to watching the content in the future.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'reading-consumption-status': {'display_name': '📑 reading-status',
#   'URI': None,
#   'label': 'reading',
#   'prompt': 'this post describes the reading status of the author in relation to a reference, such as a book or article. The author may either have read the reference in the past, is reading the reference in the present, or is looking forward to reading the reference in the future.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'listening-consumption-status': {'display_name': '🎧 listening-status',
#   'URI': None,
#   'label': 'listening',
#   'prompt': 'this post describes the listening status of the author in relation to a reference, such as a podcast or radio station. The author may have listened to the content in the past, is listening to the content in the present, or is looking forward to listening the content in the future.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'links to': {'display_name': '🔗 links-to',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e1159',
#   'label': 'other',
#   'prompt': 'This is a special tag. Use this tag if none of the tags above are suitable.',
#   'notes': 'default predicate for a mention of a URL (always applicable)',
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref', 'nan'],
#   'versions': ['v0']},
#  'reviews': {'display_name': '🧐 reviews',
#   'URI': None,
#   'label': 'review',
#   'prompt': 'this post contains a review of another reference, such as a book, article or movie. The review could be positive or negative. A review can be detailed or a simple short endorsement.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'recommends': {'display_name': '👌 recommends',
#   'URI': None,
#   'label': 'recommendation',
#   'prompt': 'The author is recommending any kind of content: an article, a movie, podcast, book, another post, etc. This tag can also be used for cases of implicit recommendation, where the author is expressing enjoyment of some content but not explicitly recommending it.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'asks-question-about': {'display_name': '❔ ask-question-about',
#   'URI': None,
#   'label': 'question',
#   'prompt': "this post is raising a question or questions about some content it's referring to. The content could be a research paper or other media like a podcast, video or blog post.",
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'Includes-quotation-from': {'display_name': '📝 quotes-from',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e649',
#   'label': 'quote',
#   'prompt': 'this post is quoting text from an article it\'s referring to. Symbols like ">" or quotation marks are often used to indicate quotations.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'Discussion': {'display_name': '🗣️ discusses',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e468',
#   'label': 'discussion',
#   'prompt': 'this post discusses how the cited reference relates to other facts or claims. For example, post might discuss how the cited reference informs questions, provides evidence, or supports or opposes claims.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'Announcement-event': {'display_name': '🗓️ announces-event',
#   'URI': None,
#   'label': 'event',
#   'prompt': 'this post includes an invitation to an event, either a real-world or an online event. Any kind of event is relevant, some examples of such events could be seminars, meetups, or hackathons. This tag shold only be used for invitations to events, not for posts describing other kinds of events.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'announcement-job': {'display_name': '📢 announces-job',
#   'URI': None,
#   'label': 'job',
#   'prompt': 'this post describes a job listing, for example a call for graduate students or faculty applications.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  'Announcement-research': {'display_name': '📢 announces-research',
#   'URI': None,
#   'label': 'announce',
#   'prompt': 'this post contains an announcement of new research. The announcement is likely made by the authors but may be a third party. We use a broad definition of research that includes classic and non-traditional outputs. Classic outputs include papers, datasets or code. Non traditional outputs can include a podcast, blog post, video explainers, etc.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']}}

# %%
notion_ontology.get_valid_templates(subject_type="post", object_type="ref")
# Out:
# [{'display_name': '👀 watching-status',
#   'URI': None,
#   'label': 'watching',
#   'prompt': 'this post describes the watching status of the author in relation to a reference, such as a video or movie. The author may have watched the content in the past, is watching the content in the present, or is looking forward to watching the content in the future.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '📑 reading-status',
#   'URI': None,
#   'label': 'reading',
#   'prompt': 'this post describes the reading status of the author in relation to a reference, such as a book or article. The author may either have read the reference in the past, is reading the reference in the present, or is looking forward to reading the reference in the future.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '🎧 listening-status',
#   'URI': None,
#   'label': 'listening',
#   'prompt': 'this post describes the listening status of the author in relation to a reference, such as a podcast or radio station. The author may have listened to the content in the past, is listening to the content in the present, or is looking forward to listening the content in the future.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '🔗 links-to',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e1159',
#   'label': 'other',
#   'prompt': 'This is a special tag. Use this tag if none of the tags above are suitable.',
#   'notes': 'default predicate for a mention of a URL (always applicable)',
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref', 'nan'],
#   'versions': ['v0']},
#  {'display_name': '🧐 reviews',
#   'URI': None,
#   'label': 'review',
#   'prompt': 'this post contains a review of another reference, such as a book, article or movie. The review could be positive or negative. A review can be detailed or a simple short endorsement.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '👌 recommends',
#   'URI': None,
#   'label': 'recommendation',
#   'prompt': 'The author is recommending any kind of content: an article, a movie, podcast, book, another post, etc. This tag can also be used for cases of implicit recommendation, where the author is expressing enjoyment of some content but not explicitly recommending it.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '❔ ask-question-about',
#   'URI': None,
#   'label': 'question',
#   'prompt': "this post is raising a question or questions about some content it's referring to. The content could be a research paper or other media like a podcast, video or blog post.",
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '📝 quotes-from',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e649',
#   'label': 'quote',
#   'prompt': 'this post is quoting text from an article it\'s referring to. Symbols like ">" or quotation marks are often used to indicate quotations.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '🗣️ discusses',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e468',
#   'label': 'discussion',
#   'prompt': 'this post discusses how the cited reference relates to other facts or claims. For example, post might discuss how the cited reference informs questions, provides evidence, or supports or opposes claims.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '🗓️ announces-event',
#   'URI': None,
#   'label': 'event',
#   'prompt': 'this post includes an invitation to an event, either a real-world or an online event. Any kind of event is relevant, some examples of such events could be seminars, meetups, or hackathons. This tag shold only be used for invitations to events, not for posts describing other kinds of events.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '📢 announces-job',
#   'URI': None,
#   'label': 'job',
#   'prompt': 'this post describes a job listing, for example a call for graduate students or faculty applications.',
#   'notes': None,
#   'valid_subject_types': ['post'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '📢 announces-research',
#   'URI': None,
#   'label': 'announce',
#   'prompt': 'this post contains an announcement of new research. The announcement is likely made by the authors but may be a third party. We use a broad definition of research that includes classic and non-traditional outputs. Classic outputs include papers, datasets or code. Non traditional outputs can include a podcast, blog post, video explainers, etc.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']}]

# %%
notion_ontology.get_valid_templates(subject_type="post", object_type="ref", as_dict=False).label.to_list()
# Out:
# ['watching',
#  'reading',
#  'listening',
#  'other',
#  'review',
#  'recommendation',
#  'question',
#  'quote',
#  'discussion',
#  'event',
#  'job',
#  'announce']

# %%
notion_ontology.get_valid_templates(subject_type="post", object_type="nan", as_dict=False).label.to_list()
# Out:
# ['missing-ref', 'dg-observation', 'dg-claim', 'dg-question', 'other']

# %%
notion_ontology.get_valid_templates(subject_type="ref", object_type="ref")
# Out:
# [{'display_name': '🧐 reviews',
#   'URI': None,
#   'label': 'review',
#   'prompt': 'this post contains a review of another reference, such as a book, article or movie. The review could be positive or negative. A review can be detailed or a simple short endorsement.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '👌 recommends',
#   'URI': None,
#   'label': 'recommendation',
#   'prompt': 'The author is recommending any kind of content: an article, a movie, podcast, book, another post, etc. This tag can also be used for cases of implicit recommendation, where the author is expressing enjoyment of some content but not explicitly recommending it.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '❔ ask-question-about',
#   'URI': None,
#   'label': 'question',
#   'prompt': "this post is raising a question or questions about some content it's referring to. The content could be a research paper or other media like a podcast, video or blog post.",
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '📝 quotes-from',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e649',
#   'label': 'quote',
#   'prompt': 'this post is quoting text from an article it\'s referring to. Symbols like ">" or quotation marks are often used to indicate quotations.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '🗣️ discusses',
#   'URI': 'https://sparontologies.github.io/cito/current/cito.html#d4e468',
#   'label': 'discussion',
#   'prompt': 'this post discusses how the cited reference relates to other facts or claims. For example, post might discuss how the cited reference informs questions, provides evidence, or supports or opposes claims.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']},
#  {'display_name': '📢 announces-research',
#   'URI': None,
#   'label': 'announce',
#   'prompt': 'this post contains an announcement of new research. The announcement is likely made by the authors but may be a third party. The research should be a paper, dataset or other type of research output that is being announced publicly.',
#   'notes': None,
#   'valid_subject_types': ['post', 'ref'],
#   'valid_object_types': ['ref'],
#   'versions': ['v0']}]
