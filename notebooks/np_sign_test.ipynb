# %%
# running example from https://vemonet.github.io/nanopub-rs/use_python.html

from nanopub_sign import Nanopub, NpProfile

# Change the RDF and private key as you wish
rdf_str = """@prefix : <http://purl.org/nanopub/temp/mynanopub#> .
@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
@prefix dc: <http://purl.org/dc/terms/> .
@prefix pav: <http://purl.org/pav/> .
@prefix prov: <http://www.w3.org/ns/prov#> .
@prefix np: <http://www.nanopub.org/nschema#> .
@prefix npx: <http://purl.org/nanopub/x/> .
@prefix ex: <http://example.org/> .

:Head {
    : np:hasAssertion :assertion ;
        np:hasProvenance :provenance ;
        np:hasPublicationInfo :pubinfo ;
        a np:Nanopublication .
}

:assertion {
    ex:mosquito ex:transmits ex:malaria .
}

:provenance {
    :assertion prov:hadPrimarySource <http://dx.doi.org/10.3233/ISU-2010-0613> .
}

:pubinfo {
    : a npx:ExampleNanopub .
}"""
private_key = "..."

# Instantiate nanopub profile
profile = NpProfile(
    name="",
    private_key=private_key,
    orcid_id="https://orcid.org/0000-0000-0000-0000",
    introduction_nanopub_uri=""
)

# Check
np = Nanopub.check(rdf_str)
print("Checked info dict:", np.info())

# Sign
np = Nanopub.sign(
    rdf=rdf_str,
    profile=profile,
)
print("Signed info dict:", np.info())

# Publish
np = Nanopub.publish(
    rdf=rdf_str,
    profile=profile,
    server_url=None,
)
print("Published info dict:", np.info())
print(np.get_rdf())
# Out:
# Checked info dict:
# ✅ Nanopub http://purl.org/nanopub/temp/mynanopub is valid: 1 valid (not trusty) without signature
#  {'uri': 'http://purl.org/nanopub/temp/mynanopub', 'ns': 'http://purl.org/nanopub/temp/mynanopub#', 'normalized_ns': 'https://w3id.org/np/', 'head': 'http://purl.org/nanopub/temp/mynanopub#Head', 'assertion': 'http://purl.org/nanopub/temp/mynanopub#assertion', 'prov': 'http://purl.org/nanopub/temp/mynanopub#provenance', 'pubinfo': 'http://purl.org/nanopub/temp/mynanopub#pubinfo', 'base_uri': 'http://purl.org/nanopub/temp/mynanopub', 'separator_before_trusty': '#', 'separator_after_trusty': '#', 'trusty_hash': '', 'signature': '', 'signature_iri': 'http://purl.org/nanopub/temp/mynanopub#sig', 'algo': '', 'public_key': '', 'orcid': '', 'published': False}
# Signed info dict: {'uri': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g', 'ns': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g#', 'normalized_ns': 'https://w3id.org/np/', 'head': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g#Head', 'assertion': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g#assertion', 'prov': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g#provenance', 'pubinfo': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g#pubinfo', 'base_uri': 'https://w3id.org/np', 'separator_before_trusty': '/', 'separator_after_trusty': '#', 'trusty_hash': 'RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g', 'signature': '', 'signature_iri': 'https://w3id.org/np/RAPy_rj3T0pIO-x3ZETHLex_wZoqTmUpaOLpC7QuPZB6g#sig', 'algo': 'RSA', 'public_key': '', 'orcid': 'https://orcid.org/0000-0000-0000-0000', 'published': False}
# Nanopub not signed, signing it before publishing
# No server URL provided, using the test server https://np.test.knowledgepixels.com/
#
# 🎉 Nanopublication published at https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM
# Published info dict: {'uri': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM', 'ns': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#', 'normalized_ns': 'https://w3id.org/np/', 'head': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#Head', 'assertion': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#assertion', 'prov': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#provenance', 'pubinfo': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#pubinfo', 'base_uri': 'https://w3id.org/np', 'separator_before_trusty': '/', 'separator_after_trusty': '#', 'trusty_hash': 'RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM', 'signature': '', 'signature_iri': 'https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#sig', 'algo': 'RSA', 'public_key': '', 'orcid': 'https://orcid.org/0000-0000-0000-0000', 'published': True}
# PREFIX this: <https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM>
# PREFIX sub: <https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM#>
# PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX schema: <http://schema.org/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX biolink: <https://w3id.org/biolink/vocab/>
# PREFIX np: <http://www.nanopub.org/nschema#>
# PREFIX prov: <http://www.w3.org/ns/prov#>
# PREFIX pav: <http://purl.org/pav/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX orcid: <https://orcid.org/>
# PREFIX npx: <http://purl.org/nanopub/x/>
#
# GRAPH sub:Head {
#   <https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM> a np:Nanopublication;
#     np:hasAssertion sub:assertion;
#     np:hasProvenance sub:provenance;
#     np:hasPublicationInfo sub:pubinfo.
# }
#
# GRAPH sub:assertion {
#   <http://example.org/mosquito>
#     <http://example.org/transmits> <http://example.org/malaria>.
# }
#
# GRAPH sub:provenance {
#   sub:assertion
#     prov:hadPrimarySource <http://dx.doi.org/10.3233/ISU-2010-0613>.
# }
#
# GRAPH sub:pubinfo {
#   <https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM> a npx:ExampleNanopub;
#     dcterms:created "2024-01-23T14:45:26.640Z"^^xsd:dateTime;
#     dcterms:creator orcid:0000-0000-0000-0000.
#
#   sub:sig
#     npx:hasAlgorithm "RSA";
#     npx:hasPublicKey "";
#     npx:hasSignature "";
#     npx:hasSignatureTarget <https://w3id.org/np/RAKObyGXmbgTYWj2iN0XGgJv0yWNDQd_DTmAWUouGfIsM>.
# }
